# %% [markdown]
# # Prompt Chaining — itinerario paso a paso
#
# > **Clasificación: Workflow.** El orden vuelos→alojamiento→actividades lo fijo yo en el código; ningún agente decide llamar a otro.
#
# **Por qué este patrón aquí:** planificar un viaje tiene un orden natural y fijo — primero sabes cuándo vuelas, luego reservas el alojamiento para esas fechas, luego encajas actividades en los días que queden. Cada paso necesita el resultado exacto del anterior.

# %%
# %pip install crewai --quiet
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()

import nest_asyncio
nest_asyncio.apply()

# %%
from crewai import Agent, Task, Crew, Process

destino, dias, personas, presupuesto = "Islandia", 5, 2, 2200

vuelos_agent = Agent(
    role="Especialista en Vuelos",
    goal="Encontrar las mejores opciones de vuelo dentro de presupuesto",
    backstory="Conoces tarifas y aerolíneas para rutas europeas.",
)
vuelos_task = Task(
    description=f"Propón opciones de vuelo a {destino} para {personas} personas, {dias} días. Presupuesto total del viaje: {presupuesto}€.",
    expected_output="2-3 opciones de vuelo con precio aproximado y fechas, y cuánto presupuesto queda tras los vuelos.",
    agent=vuelos_agent,
)

alojamiento_agent = Agent(
    role="Especialista en Alojamientos",
    goal="Encontrar el alojamiento con mejor relación precio-calidad comparando plataformas",
    backstory="Comparas Airbnb y Booking para encontrar la opción que más rinda dentro del presupuesto restante.",
)
alojamiento_task = Task(
    description="Con el presupuesto restante tras los vuelos (ver paso anterior), compara 2 opciones de alojamiento — una en Airbnb y otra en Booking — para las fechas elegidas.",
    expected_output="2 opciones de alojamiento (una de cada plataforma) con precio por noche y zona, indicando cuál optimiza mejor el presupuesto restante.",
    agent=alojamiento_agent,
    context=[vuelos_task],
)

actividades_agent = Agent(
    role="Especialista en Actividades",
    goal="Proponer un plan de actividades dentro del presupuesto restante",
    backstory="Conoces atracciones, restaurantes y experiencias locales.",
)
actividades_task = Task(
    description=f"Con el presupuesto restante tras vuelos y alojamiento, propón un plan de actividades para los {dias} días.",
    expected_output="Un itinerario día por día con actividades y coste estimado, sin pasarse del presupuesto restante.",
    agent=actividades_agent,
    context=[vuelos_task, alojamiento_task],
)

crew = Crew(
    agents=[vuelos_agent, alojamiento_agent, actividades_agent],
    tasks=[vuelos_task, alojamiento_task, actividades_task],
    process=Process.sequential,
    verbose=True,
)

result = await crew.kickoff_async()
print(result.raw)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 831cff3b-040c-4b9c-8c5a-927d55ccde51                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...
