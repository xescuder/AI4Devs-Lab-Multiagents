# %% [markdown]
# # Prompt Chaining, itinerario paso a paso
#
# Clasificación: **Workflow.** El orden vuelos→alojamiento→actividades lo fijo yo en el código; ningún agente decide llamar a otro.
#
# Planificar un viaje tiene un orden natural: primero sabes cuándo vuelas, luego reservas alojamiento para esas fechas, luego encajas actividades en los días que quedan. Cada paso necesita la salida del anterior, así que prompt chaining encaja bien.
#
# Los agentes y tareas van en YAML (`config/agents.yaml`, `config/tasks.yaml`), la orquestación en `viajes_crew.py` con `@CrewBase`.

# %%
# !uv pip install -r requirements.txt --quiet

# %%
from dotenv import load_dotenv
import nest_asyncio

load_dotenv()
nest_asyncio.apply()

# %% [markdown]
# ## Por qué YAML externo en vez de definir todo en código
#
# CrewAI recomienda configurar agentes y tareas en YAML como approach por defecto. Las razones son prácticas:
#
# 1. **Separar qué hace cada agente de cómo se orquesta.** Los prompts (role, goal, backstory, description) cambian mucho más que la lógica de conexión. Con YAML puedes ajustar un prompt sin tocar Python.
#
# 2. **Variables interpoladas.** Los YAML aceptan `{variable}` que se resuelven con los `inputs` del kickoff. Esto te permite reusar la misma crew para distintos destinos, presupuestos o duraciones sin duplicar código.
#
# 3. **El código Python queda mínimo.** La clase `@CrewBase` solo conecta agentes con tareas y define el proceso. Si miras `viajes_crew.py`, casi no hay lógica: los métodos `@agent` y `@task` solo devuelven objetos con la config que viene del YAML.
#
# 4. **Es lo que genera `crewai create`.** El CLI de CrewAI scaffoldea la estructura `config/agents.yaml` + `config/tasks.yaml` + `crew.py` por defecto, así que seguir esta convención hace que el proyecto sea familiar para cualquiera que haya usado el framework.
#
# La alternativa (definir todo inline en Python) funciona, pero en cuanto tienes 3-4 agentes los bloques de texto en el código se vuelven difíciles de leer y de mantener.

# %% [markdown]
# ## Configuración de agentes (`config/agents.yaml`)
#
# Cada clave de primer nivel (p.ej. `vuelos:`) es el identificador del agente, referenciado desde `tasks.yaml` y desde `@CrewBase`.
#
# | Atributo | Tipo | Qué hace |
# |----------|------|----------|
# | `role` | `str` | La función del agente en la crew. Determina qué tipo de tareas aborda. |
# | `goal` | `str` | Objetivo que el agente intenta cumplir. Guía sus decisiones en cada iteración. |
# | `backstory` | `str` | Contexto y personalidad. Le da al LLM un personaje consistente para razonar. |
# | `llm` | `str` | Modelo a usar: `provider/model` o solo el nombre (p.ej. `gpt-4.1-mini`). |
# | `verbose` | `bool` | Si `true`, imprime cada paso de razonamiento. Útil en desarrollo. |

# %%
# %pycat config/agents.yaml
# Out:
# vuelos:
#   role: "Especialista en Vuelos"
#   goal: "Encontrar las mejores opciones de vuelo dentro de presupuesto"
#   backstory: >
#     Conoces tarifas y aerolineas para rutas europeas.
#   llm: "gpt-4.1-mini"
#   verbose: true
#
# alojamiento:
#   role: "Especialista en Alojamientos"
#   goal: "Encontrar el alojamiento con mejor relacion precio-calidad comparando plataformas"
#   backstory: >
#     Comparas Airbnb y Booking para encontrar la opcion que mas rinda
#     dentro del presupuesto restante.
#   llm: "gpt-4.1-mini"
#   verbose: true
#
# actividades:
#   role: "Especialista en Actividades"
#   goal: "Proponer un plan de actividades dentro del presupuesto restante"
#   backstory: >
#     Conoces atracciones, restaurantes y experiencias locales.
#   llm: "gpt-4.1-mini"
#   verbose: true
#
# coche:
#   role: "Especialista en Rutas en Coche"
#   goal: "Planificar rutas en coche entre las zonas del viaje, ya sea coche propio o de alquiler"
#   backstory: >
#     Calculas rutas por carretera, tiempos de conduccion, peajes y costes
#     de combustible o alquiler. Si el viajero usa su propio coche, omites
#     el coste de alquiler y te centras en ruta, combustible y peajes.
#   llm: "gpt-4.1-mini"
#   verbose: true
#
# itinerario:
#   role: "Director de Itinerario"
#   goal: "Ensamblar un itinerario día a día con horarios, distancias y presupuesto consolidado"
#   backstory: >
#     Recibes los reportes de vuelos, alojamiento, actividades y transporte
#     y los integras en un plan coherente con timeline, km entre puntos
#     y desglose de costes. Si el total supera el presupuesto, ajustas.
#   llm: "gpt-4.1-mini"
#   verbose: true
#
# transporte:
#   role: "Especialista en Transporte"
#   goal: "Proponer opciones de transporte para moverse durante el viaje"
#   backstory: >
#     Conoces opciones de transporte local, alquiler de coches y transporte público.
#   llm: "gpt-4.1-mini"
#   verbose: true

# %% [markdown]
# ## Configuración de tareas (`config/tasks.yaml`)
#
# Cada clave de primer nivel (p.ej. `vuelos_task:`) es el identificador de la tarea, referenciado desde `@CrewBase`.
#
# | Atributo | Tipo | Qué hace |
# |----------|------|----------|
# | `description` | `str` | Lo que el agente debe hacer. Acepta variables `{variable}` que se interpolan con los inputs del kickoff. |
# | `expected_output` | `str` | Cómo se ve la respuesta terminada. El agente lo usa para saber cuándo parar. |
# | `agent` | `str` | Agente asignado (debe coincidir con una clave en `agents.yaml`). |

# %%
# %pycat config/tasks.yaml
# Out:
# vuelos_task:
#   description: >
#     Propon opciones de vuelo a {destino} para {personas} personas y {dias} dias.
#     Presupuesto total del viaje: {presupuesto} EUR.
#   expected_output: >
#     2-3 opciones de vuelo con precio aproximado y fechas,
#     y cuanto presupuesto queda tras los vuelos.
#   agent: vuelos
#
# alojamiento_task:
#   description: >
#     Con el presupuesto restante tras los vuelos, compara 2 opciones de alojamiento:
#     una en Airbnb y otra en Booking para las fechas elegidas.
#   expected_output: >
#     2 opciones de alojamiento (una de cada plataforma) con precio por noche y zona,
#     indicando cual optimiza mejor el presupuesto restante.
#   agent: alojamiento
#
# actividades_task:
#   description: >
#     Con el presupuesto restante tras vuelos y alojamiento,
#     propon un plan de actividades para los {dias} dias.
#   expected_output: >
#     Itinerario dia por dia con actividades y costo estimado,
#     sin pasarse del presupuesto restante.
#   agent: actividades
#
#
# transporte_task:
#   description: >
#     Con el presupuesto restante tras vuelos, alojamiento y actividades,
#     propon opciones de transporte para moverse durante los {dias} dias.
#   expected_output: >
#     2-3 opciones de transporte (alquiler de coche, transporte público, etc.)
#     con precio aproximado y disponibilidad, indicando cual optimiza mejor el presupuesto restante.
#   agent: transporte
#
# coche_task:
#   description: >
#     El viajero va a recorrer {destino} en coche ({tipo_coche}).
#     Planifica la ruta por carretera entre las zonas principales para {dias} dias.
#     Incluye km entre puntos, tiempo estimado de conduccion, peajes y coste de combustible.
#     Si es coche de alquiler, incluye precio aproximado del alquiler.
#   expected_output: >
#     Ruta dia a dia con km, tiempo de conduccion, peajes, combustible
#     y coste de alquiler si aplica.
#   agent: coche
#
# itinerario_task:
#   description: >
#     Con los reportes de vuelos, alojamiento, actividades y transporte,
#     ensambla el itinerario final dia a dia para {personas} personas en {destino} durante {dias} dias.
#     Para cada dia incluye: horario aproximado, actividades, desplazamientos con km entre puntos,
#     alojamiento de esa noche y coste del dia.
#     Al final incluye un resumen con el coste total vs presupuesto de {presupuesto} EUR.
#   expected_output: >
#     Itinerario dia a dia con horario, actividades, km entre puntos, alojamiento,
#     coste por dia y resumen final con total vs presupuesto.
#   agent: itinerario
#   markdown: true
#   output_file: "itinerario_final.md"

# %% [markdown]
# ## Cómo funciona la Crew (`viajes_crew_basic.py`)
#
# Una Crew es el objeto que junta agentes, tareas y proceso de ejecución. La clase Python usa `@CrewBase` y un conjunto de decoradores que conectan los YAML con la lógica:
#
# ### Decoradores
#
# | Decorador | Para qué sirve |
# |-----------|----------------|
# | `@CrewBase` | Marca la clase como crew. Carga automáticamente `agents_config` y `tasks_config` desde los YAML. |
# | `@agent` | Registra un método como fábrica de agente. El nombre del método debe coincidir con la clave en `agents.yaml`. |
# | `@task` | Registra un método como fábrica de tarea. El nombre del método debe coincidir con la clave en `tasks.yaml`. |
# | `@crew` | Marca el método que construye y devuelve el objeto `Crew` final. |
#
# ### Atributos del `Crew()`
#
# | Atributo | Qué hace |
# |----------|----------|
# | `agents` | Lista de agentes que participan. Se pueden recoger automáticamente con `self.agents`, o listarlos a mano como en este fichero. |
# | `tasks` | Lista de tareas a ejecutar, en el orden en que se pasan. |
# | `process` | Cómo se ejecutan las tareas. `Process.sequential` las corre una tras otra (la salida de cada una pasa como contexto a la siguiente). |
# | `verbose` | Si `True`, imprime logs de ejecución de toda la crew. |
#
# ### Atributos usados en las tareas (dentro de Python)
#
# | Atributo | Qué hace |
# |----------|----------|
# | `context` | Lista de tareas cuya salida se inyecta como contexto. En `itinerario_task` se usa para recibir los resultados de vuelos, alojamiento, actividades y transporte. |

# %%
# %pycat viajes_crew_basic.py
# Out:
# from __future__ import annotations
#
# from crewai import Agent, Crew, Process, Task
# from crewai.project import CrewBase, agent, crew, task
#
# @CrewBase
# class ViajesCrewBasic:
#     """Crew secuencial para plan de viaje sin tools ni mcps asignadas a los agentes."""
#
#     agents_config = "./config/agents.yaml"
#     tasks_config = "./config/tasks.yaml"
#
#     @agent
#     def vuelos(self) -> Agent:
#         return Agent(config=self.agents_config["vuelos"])
#
#     @agent
#     def alojamiento(self) -> Agent:
#         return Agent(config=self.agents_config["alojamiento"])
#
#     @agent
#     def actividades(self) -> Agent:
#         return Agent(config=self.agents_config["actividades"])
#
#     @agent
#     def transporte(self) -> Agent:
#         return Agent(config=self.agents_config["transporte"])
#
#     @agent
#     def coche(self) -> Agent:
#         return Agent(config=self.agents_config["coche"])
#
#     @agent
#     def itinerario(self) -> Agent:
#         return Agent(config=self.agents_config["itinerario"])
#
#     @task
#     def vuelos_task(self) -> Task:
#         return Task(config=self.tasks_config["vuelos_task"])
#
#     @task
#     def alojamiento_task(self) -> Task:
#         return Task(config=self.tasks_config["alojamiento_task"])
#
#     @task
#     def actividades_task(self) -> Task:
#         return Task(config=self.tasks_config["actividades_task"])
#
#
#     @task
#     def transporte_task(self) -> Task:
#         return Task(config=self.tasks_config["transporte_task"])
#
#     @task
#     def coche_task(self) -> Task:
#         return Task(config=self.tasks_config["coche_task"])
#
#     @task
#     def itinerario_task(self) -> Task:
#         return Task(
#             config=self.tasks_config["itinerario_task"],
#             context=[self.vuelos_task(), self.alojamiento_task(), self.actividades_task(), self.transporte_task()],
#         )
#
#     @crew
#     def crew(self) -> Crew:
#         return Crew(
#             agents=[self.vuelos(), self.alojamiento(), self.actividades(), self.transporte(), self.itinerario()],
#             tasks=[self.vuelos_task(), self.alojamiento_task(), self.actividades_task(), self.transporte_task(), self.itinerario_task()],
#             process=Process.sequential,
#             verbose=True
#         )

# %%
from viajes_crew_basic import ViajesCrewBasic

inputs = {
    "destino": "Islandia",
    "dias": 10,
    "personas": 2,
    "presupuesto": 2200,
}

trip = ViajesCrewBasic()
result = await trip.crew().kickoff_async(inputs=inputs)
print(result.raw)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: ViajesCrewBasic                                                                                          │
# │  ID: 0098c316-640d-4f81-8b0f-76618e1cde03                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: vuelos_task                                                                                              │
# │  ID: be3b2679-d221-4787-ac33-f4d06858f850                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Especialista en Vuelos                                                                                  │
# │                                                                                                                 │
# │  Task: Propon opciones de vuelo a Islandia para 2 personas y 10 dias. Presupuesto total del viaje: 2200 EUR.    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Especialista en Vuelos                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Claro, para ayudarte a planificar un viaje de 10 días para dos personas a Islandia con un presupuesto total    │
# │  de 2200 EUR, vamos a considerar vuelos de ida y vuelta desde una ciudad europea con buenas conexiones a        │
# │  Islandia, como Madrid, Barcelona, o Londres, ya que suelen tener precios competitivos.                         │
# │                                                                                                                 │
# │  ### Opción 1: Vuelo Madrid (MAD) – Reikiavik (KEF) con Vueling y Icelandair                                    │
# │  - **Fechas aproximadas:** Ida 5 de septiembre, regreso 15 de septiembre                                        │
# │  - **Precio aproximado por persona:** 250 EUR ida y vuelta                                                      │
# │  - **Total para 2 personas:** 500 EUR                                                                           │
# │  - **Detalles:** Vuelo directo o con una escala corta. Vueling e Icelandair suelen tener ofertas en esta ruta.  │
# │  - **Presupuesto restante después de los vuelos:** 2200 EUR - 500 EUR = **1700 EUR**                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Opción 2: Vuelo Barcelona (BCN) – Reikiavik (KEF) con Ryanair / Wizz Air                                   │
# │  - **Fechas aproximadas:** Ida 10 de septiembre, regreso 20 de septiembre                                       │
# │  - **Precio aproximado por persona:** 190 EUR ida y vuelta                                                      │
# │  - **Total para 2 personas:** 380 EUR                                                                           │
# │  - **Detalles:** Vuelos low cost con escalas. Requiere flexibilidad y compra anticipada.                        │
# │  - **Presupuesto restante después de los vuelos:** 2200 EUR - 380 EUR = **1820 EUR**                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Opción 3: Vuelo Londres (LGW) – Reikiavik (KEF) con EasyJet o British Airways                              │
# │  - **Fechas aproximadas:** Ida 8 de septiembre, regreso 18 de septiembre                                        │
# │  - **Precio aproximado por persona:** 220 EUR ida y vuelta                                                      │
# │  - **Total para 2 personas:** 440 EUR                                                                           │
# │  - **Detalles:** Vuelo directo con buena frecuencia. Londres es un aeropuerto con muchas conexiones económicas  │
# │  a Islandia.                                                                                                    │
# │  - **Presupuesto restante después de los vuelos:** 2200 EUR - 440 EUR = **1760 EUR**                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Conclusión:                                                                                                │
# │  Las opciones más económicas para vuelos ida y vuelta para dos personas a Islandia rondan entre 380 y 500 EUR.  │
# │  Esto deja un presupuesto amplio para alojamiento, transporte local y actividades durante sus 10 días (de 1700  │
# │  EUR a 1820 EUR restantes).                                                                                     │
# │                                                                                                                 │
# │  Si quieres, también puedo ayudarte a buscar alojamiento y tours dentro del presupuesto restante. ¿Deseas?      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: vuelos_task                                                                                              │
# │  Agent: Especialista en Vuelos                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: alojamiento_task                                                                                         │
# │  ID: 41b093a6-6835-4688-9148-a21f14094ba0                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Especialista en Alojamientos                                                                            │
# │                                                                                                                 │
# │  Task: Con el presupuesto restante tras los vuelos, compara 2 opciones de alojamiento: una en Airbnb y otra en  │
# │  Booking para las fechas elegidas.                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Especialista en Alojamientos                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Perfecto, tomando en cuenta las fechas y el presupuesto restante tras elegir una opción de vuelo, voy a        │
# │  comparar dos opciones de alojamiento — una en Airbnb y otra en Booking — para un viaje de aproximadamente 10   │
# │  noches a Reikiavik y alrededores (zona clave para alojarse en Islandia).                                       │
# │                                                                                                                 │
# │  Tomaré como ejemplo la opción de vuelo desde Barcelona (opción 2) con presupuesto restante mayor: **1820       │
# │  EUR** para alojamiento, transporte y actividades.                                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Opción 1 en Airbnb                                                                                         │
# │                                                                                                                 │
# │  - **Alojamiento:** Apartamento entero en Reikiavik centro: "Cozy Central Apartment"                            │
# │  - **Zona:** Centro de Reikiavik, cerca de Laugavegur (calle principal comercial, buena ubicación para          │
# │  turismo)                                                                                                       │
# │  - **Precio por noche:** 110 EUR                                                                                │
# │  - **Duración:** 10 noches                                                                                      │
# │  - **Total alojamiento:** 1100 EUR                                                                              │
# │  - **Detalles:**                                                                                                │
# │    - Apartamento privado completamente equipado.                                                                │
# │    - WiFi, cocina, lavadora, calefacción.                                                                       │
# │    - Muy buena recepción para viajeros y comentarios positivos por limpieza y ubicación.                        │
# │  - **Ventajas:** Privacidad, posibilidad de cocinar para ahorrar en comidas, zona céntrica para caminar a       │
# │  lugares de interés.                                                                                            │
# │  - **Acceso:** Fácil transporte público y a 5 min a pie del centro histórico.                                   │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Opción 2 en Booking                                                                                        │
# │                                                                                                                 │
# │  - **Alojamiento:** Hotel Alda Reykjavik Downtown                                                               │
# │  - **Zona:** Centro de Reikiavik, también muy cerca de Laugavegur.                                              │
# │  - **Precio por noche:** 140 EUR (habitación doble estándar, sin desayuno incluido)                             │
# │  - **Duración:** 10 noches                                                                                      │
# │  - **Total alojamiento:** 1400 EUR                                                                              │
# │  - **Detalles:**                                                                                                │
# │    - Hotel bien valorado con recepción 24h.                                                                     │
# │    - Habitaciones con baño privado, limpieza diaria.                                                            │
# │    - Tiene cafetería y restaurante propios.                                                                     │
# │    - Buena relación calidad-calidad en la zona centro.                                                          │
# │  - **Ventajas:** Mayor comodidad tipo hotel, posibilidad de reservar cancelación gratuita.                      │
# │  - **Extras:** Cerca de museos, bares y restaurantes, ideal si prefieres salir a comer fuera.                   │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Comparación y optimización del presupuesto                                                                 │
# │                                                                                                                 │
# │  | Plataforma | Precio total 10 noches | Precio/noche | Zona               | Tipo alojamiento      |            │
# │  Comentarios                       |                                                                            │
# │  |------------|--------------------|------------|---------------------|----------------------|----------------  │
# │  ------------------|                                                                                            │
# │  | Airbnb     | 1100 EUR           | 110 EUR    | Reikiavik centro    | Apartamento entero   | Mejor opción     │
# │  para ahorro y flexibilidad (cocina), buena ubicación. |                                                        │
# │  | Booking    | 1400 EUR           | 140 EUR    | Reikiavik centro    | Hotel 3 estrellas    | Más comodidad,   │
# │  servicio hotelero, pero más caro y sin cocina.          |                                                      │
# │                                                                                                                 │
# │  - **Presupuesto restante alojamiento + vuelos:** 1820 EUR                                                      │
# │  - Si eliges **Airbnb**, te quedarán aproximadamente **720 EUR** para transporte y actividades.                 │
# │  - Si optas por **Booking**, te quedarán aproximadamente **420 EUR** para transporte y actividades.             │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Conclusión                                                                                                 │
# │                                                                                                                 │
# │  Para maximizar el presupuesto restante y obtener buena calidad, la mejor opción es **el apartamento en Airbnb  │
# │  a 110 EUR/noche**, que permite ahorrar 300 EUR respecto al hotel de Booking y brinda mayor autonomía y         │
# │  comodidad para estancias prolongadas, especialmente para dos personas.                                         │
# │                                                                                                                 │
# │  Si prefieres mayor comodidad hotelera y no te importa pagar un poco más, la opción de Booking es válida, pero  │
# │  reduce tu margen para tours y transporte.                                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  Si deseas, también puedo ayudarte a buscar alquiler de coche o tours dentro del presupuesto que quede tras     │
# │  elegir el alojamiento.                                                                                         │
# │                                                                                                                 │
# │  ¿Quieres que continúe con recomendaciones para transporte o actividades?                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: alojamiento_task                                                                                         │
# │  Agent: Especialista en Alojamientos                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: actividades_task                                                                                         │
# │  ID: d06b53b5-d81a-4266-846c-d009c51949b1                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Especialista en Actividades                                                                             │
# │                                                                                                                 │
# │  Task: Con el presupuesto restante tras vuelos y alojamiento, propon un plan de actividades para los 10 dias.   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Especialista en Actividades                                                                             │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Perfecto, tomando la mejor combinación para aprovechar el presupuesto, elegiremos la opción de vuelo desde     │
# │  Barcelona (380 EUR para dos personas) y alojamiento en Airbnb "Cozy Central Apartment" en Reikiavik centro     │
# │  (1100 EUR para 10 noches). El presupuesto quedaría así:                                                        │
# │                                                                                                                 │
# │  - Vuelo para 2 personas: 380 EUR                                                                               │
# │  - Alojamiento 10 noches: 1100 EUR                                                                              │
# │                                                                                                                 │
# │  **Total gastado en vuelos + alojamiento** = 1480 EUR                                                           │
# │  **Presupuesto total**: 2200 EUR                                                                                │
# │  **Presupuesto restante para transporte y actividades** = 2200 - 1480 = **720 EUR**                             │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Plan detallado de actividades para 10 días para 2 personas en Islandia (presupuesto 720 EUR)                │
# │                                                                                                                 │
# │  ### Nota general sobre transporte:                                                                             │
# │  - La opción más cómoda es alquilar un coche para flexibilidad y accesibilidad a lugares naturales.             │
# │  - Alquiler de coche pequeño por 10 días puede costar aproximadamente entre 300-350 EUR (depende de agencia,    │
# │  seguro básico incluido).                                                                                       │
# │  - Para optimizar el presupuesto, recomiendo alquiler económico con compañía local o booking anticipado.        │
# │  - Restará aprox 360-420 EUR para actividades.                                                                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Itinerario Día por Día con Costos Aproximados                                                               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Día 1: Llegada a Reikiavik y Exploración del Centro                                                        │
# │  - Llegada, check-in en Airbnb.                                                                                 │
# │  - Paseo a pie por el centro: calle Laugavegur, Hallgrímskirkja (visita gratuita a iglesia), centro cultural    │
# │  Harpa.                                                                                                         │
# │  - Cena en un restaurante local económico (ej. "Noodle Station" o "Bæjarins Beztu Pylsur" famoso por perritos   │
# │  calientes).                                                                                                    │
# │  - **Costo estimado comida:** 25 EUR por persona = 50 EUR                                                       │
# │  - Transporte: caminata                                                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Día 2: Círculo Dorado (Tour autoguiado con coche alquilado)                                                │
# │  - Visita al Parque Nacional Þingvellir (gratis)                                                                │
# │  - Geysir y Strokkur (gratis)                                                                                   │
# │  - Cascada Gullfoss (gratis)                                                                                    │
# │  - Picnic comprado en supermercado para almuerzo                                                                │
# │  - Cena en Reikiavik (pizzería o comida local simple)                                                           │
# │  - **Alquiler coche día completo:** inclusión dentro del alquiler total 300-350 EUR                             │
# │  - Comidas (picnic + cena): aprox 40 EUR                                                                        │
# │  - Entradas: gratuitas                                                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Día 3: Península de Reykjanes (zona geotermal y laguna Azul)                                               │
# │  - Visita a zona geotermal Krýsuvík (gratis)                                                                    │
# │  - Faro de Reykjanesviti                                                                                        │
# │  - Laguna Azul (Blue Lagoon) 2 horas (entrada estándar approx 65 EUR por persona)                               │
# │  - Comidas: desayuno en apartamento, cena simple fuera (40 EUR)                                                 │
# │  - Laguna Azul 130 EUR para dos personas                                                                        │
# │  - Transporte: coche alquilado                                                                                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Día 4: Costa Sur - Cascadas y playas negras                                                                │
# │  - Seljalandsfoss y Gljúfrabúi (gratis)                                                                         │
# │  - Skógafoss (gratis)                                                                                           │
# │  - Playa de arena negra Reynisfjara (gratis)                                                                    │
# │  - Almuerzo picnic, cena en el apartamento (compras supermercado)                                               │
# │  - Comidas: aprox 30 EUR (supermercado y picnic)                                                                │
# │  - Transporte: coche                                                                                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Día 5: Excursión a un glaciar o Cueva de hielo (opcional)                                                  │
# │  - Tour guiado a cueva de hielo o glaciar (desde 100 EUR por persona aprox)                                     │
# │  - Cena en Reykjavik: comida económica (40 EUR)                                                                 │
# │  - Total excursión: 200 EUR para dos                                                                            │
# │  - Transporte incluido en tour                                                                                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Día 6: Día libre en Reikiavik y museos                                                                     │
# │  - Visita museos: Museo Nacional de Islandia (15 EUR por persona)                                               │
# │  - Museo de Arte de Reikiavik (10 EUR por persona)                                                              │
# │  - Paseo por antiguos barrios y puerto                                                                          │
# │  - Cena en restaurante pequeño 50 EUR                                                                           │
# │  - Total museos: 50 EUR                                                                                         │
# │  - Transporte: caminata o bus local (billete sencillo aprox 4 EUR)                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Día 7: Excursión a la Laguna Jökulsárlón (día completo, tour con bus)                                      │
# │  - Tour en bus desde Reikiavik a Laguna Glaciar y Playa Diamante                                                │
# │  - Precio tour: aprox 120 EUR por persona (incluye guía y transporte)                                           │
# │  - Comida picnic incluida o comprada                                                                            │
# │  - Total tour: 240 EUR                                                                                          │
# │  - Transporte incluido en tour                                                                                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Día 8: Día en Reikiavik o relax y tiendas de diseño local                                                  │
# │  - Visita cafeterías, tiendas locales                                                                           │
# │  - Actividad gratuita: sendero al Monte Esja (mirador de Reikiavik)                                             │
# │  - Cena económica en ciudad (30 EUR)                                                                            │
# │  - Transporte caminata                                                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Día 9: Baño en piscina geotermal local (Laguna secreta o Laugardalslaug)                                   │
# │  - Entrada a piscina pública geotermal: aprox 10 EUR por persona                                                │
# │  - Visita barrio de Laugardalur (parques, jardines)                                                             │
# │  - Cena en apartamento (recetas caseras) 20 EUR                                                                 │
# │  - Transporte en bus o coche                                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Día 10: Últimas compras y paseo por Reikiavik                                                              │
# │  - Visita tiendas de souvenirs o mercado local                                                                  │
# │  - Almuerzo en cafetería (30 EUR)                                                                               │
# │  - Preparar salida/descanso                                                                                     │
# │  - Transporte caminata                                                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Resumen y Costos Aproximados                                                                                │
# │                                                                                                                 │
# │  | Concepto                          | Costo total aprox (EUR) |                                                │
# │  |----------------------------------|-------------------------|                                                 │
# │  | Alquiler coche 10 días            | 320 EUR                 |                                                │
# │  | Comidas y cenas (media 35 EUR/día)| 350 EUR                 |                                                │
# │  | Laguna Azul (día 3)               | 130 EUR                 |                                                │
# │  | Tour glaciar (día 5)              | 200 EUR                 |                                                │
# │  | Museo Nacional + arte (día 6)    | 50 EUR                  |                                                 │
# │  | Tour Laguna Jökulsárlón (día 7)  | 240 EUR                 |                                                 │
# │  | Piscina geotermal (día 9)        | 20 EUR                  |                                                 │
# │  | Transporte bus ocasional          | 20 EUR                  |                                                │
# │  | **Total actividades + comidas + transporte** | **1330 EUR** |                                                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Ajustes necesarios                                                                                          │
# │                                                                                                                 │
# │  El total estimado excede el presupuesto disponible de 720 EUR, por lo que para ajustarnos al presupuesto       │
# │  propondré las siguientes modificaciones:                                                                       │
# │                                                                                                                 │
# │  1. **Reducir días con tours caros o prescindir de uno**:                                                       │
# │     - Omitir el tour de la Laguna Jökulsárlón (240 EUR) o la visita a la cueva de hielo (200 EUR) para ahorrar  │
# │  al menos 200 EUR.                                                                                              │
# │                                                                                                                 │
# │  2. **Comidas más económicas y autoservicio**:                                                                  │
# │     - Cocinar más en apartamento, reducir comer fuera a máximo 2-3 veces. Esto puede reducir unos 100 EUR.      │
# │                                                                                                                 │
# │  3. **Laguna Azul opcional**:                                                                                   │
# │     - Cambiar Laguna Azul por piscina geotermal pública más barata (10 EUR pp), ahorrando cerca de 120 EUR.     │
# │                                                                                                                 │
# │  4. **Actividades gratuitas o económicas**:                                                                     │
# │     - Más senderismo, baños en piscinas públicas gratuitas o baratas, visitar paisajes naturales.               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Plan revisado para presupuesto **720 EUR**                                                                 │
# │                                                                                                                 │
# │  | Concepto                          | Costo ajustado (EUR)    |                                                │
# │  |----------------------------------|------------------------|                                                  │
# │  | Alquiler coche 10 días            | 320 EUR                |                                                 │
# │  | Comidas (priorizando cocina)     | 200 EUR                |                                                  │
# │  | Laguna Azul (dado corte: piscina pública) | 20 EUR          |                                                │
# │  | Tour glaciar o Laguna Jökulsárlón* | 0 - 200 EUR (elige una; si presupuesto máximo 720 EUR, no se hace) |    │
# │  | Museos y transporte              | 20 EUR                 |                                                  │
# │  | Total actividades + comida + transporte | 560 EUR             |                                              │
# │                                                                                                                 │
# │  De esta forma pueden disfrutar la mayoría de días haciendo turismo natural, senderismo y paseos por            │
# │  Reykjavik, maximizando la experiencia y respetando el presupuesto.                                             │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  # Itinerario Final día a día (presupuesto optimizado)                                                          │
# │                                                                                                                 │
# │  | Día | Actividad                                                                                          |   │
# │  Costo aprox. (EUR)       |                                                                                     │
# │  |------|-------------------------------------------------------------------------------------------------|---  │
# │  -----------------------|                                                                                       │
# │  | 1    | Llegada y paseo por Reikiavik, cena en apartamento o económica                                   |    │
# │  25                       |                                                                                     │
# │  | 2    | Círculo Dorado autoguiado con coche, picnic                                                     | 30  │
# │  |                                                                                                              │
# │  | 3    | Península de Reykjanes, baño en piscina pública geotermal (Laguna Azul descartada)               |    │
# │  20                       |                                                                                     │
# │  | 4    | Costa Sur: cascadas y playa negra, picnic                                                       | 20  │
# │  |                                                                                                              │
# │  | 5    | Día de senderismo o relax, explorar Reikiavik (sin tours caros)                                 | 10  │
# │  |                                                                                                              │
# │  | 6    | Museos y paseos culturales, cena en apartamento                                                 | 15  │
# │  |                                                                                                              │
# │  | 7    | Día libre para caminatas o excursión pequeña local                                              | 15  │
# ...
# │  - **Alojamiento:**                                                                                             │
# │    Airbnb                                                                                                       │
# │  - **Coste del día:**                                                                                           │
# │    Comidas / cafés 20 EUR                                                                                       │
# │    Bus 4 EUR                                                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  # Día 8: Día en piscina geotermal local y parque Laugardalur                                                   │
# │  - **Horario aproximado:**                                                                                      │
# │    Mañana piscina Laugardalslaug (famosa en Reykjavik)                                                          │
# │    Reposo y paseo por parque                                                                                    │
# │  - **Actividades:**                                                                                             │
# │    Baño, relajación y caminatas suaves                                                                          │
# │  - **Desplazamientos:**                                                                                         │
# │    Movilidad local a piscina en bus o coche                                                                     │
# │  - **Alojamiento:**                                                                                             │
# │    Airbnb                                                                                                       │
# │  - **Coste del día:**                                                                                           │
# │    Entrada piscina 10 EUR/persona = 20 EUR                                                                      │
# │    Comidas 15 EUR                                                                                               │
# │    Kombustible/bus 5 EUR                                                                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  # Día 9: Visita a pequeñas excursiones cercanas al Reykjanes (opcional y gratis)                               │
# │  - **Horario aproximado:**                                                                                      │
# │    Explorar áreas naturales cerca de Reikiavik, ej. Senderos en alrededores                                     │
# │  - **Actividades:**                                                                                             │
# │    Exploración gratis / senderismo                                                                              │
# │  - **Desplazamientos:**                                                                                         │
# │    Coche para distancias cortas (20-30 km)                                                                      │
# │  - **Alojamiento:**                                                                                             │
# │    Airbnb                                                                                                       │
# │  - **Coste del día:**                                                                                           │
# │    Comidas 20 EUR                                                                                               │
# │    Combustible 6 EUR aprox.                                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  # Día 10: Últimas compras, paseo y preparación para salida                                                     │
# │  - **Horario aproximado:**                                                                                      │
# │    Mañana libre para compras de último minuto                                                                   │
# │    Tarde descanso y organizar maletas                                                                           │
# │  - **Actividades:**                                                                                             │
# │    Compras, paseo suave por ciudad                                                                              │
# │  - **Desplazamientos:**                                                                                         │
# │    Caminata y transporte local (bus)                                                                            │
# │  - **Alojamiento:**                                                                                             │
# │    Airbnb (noche final)                                                                                         │
# │  - **Coste del día:**                                                                                           │
# │    Comidas 15 EUR                                                                                               │
# │    Transporte público 4 EUR                                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  # Consolidado de Kilómetros y Costes por Día                                                                   │
# │                                                                                                                 │
# │  | Día | Km aprox. (coche) | Actividades principales                              | Coste aprox. (EUR) |        │
# │  |------|------------------|-----------------------------------------------------|--------------------|         │
# │  | 1    | 0                | Llegada, paseo urbano                                | 50 (cena)          |        │
# │  | 2    | 233              | Círculo Dorado                                       | 62 (coche + comida) |       │
# │  | 3    | 105              | Península Reykjanes + piscina pública                | 53 (coche + piscina +       │
# │  comida) |                                                                                                      │
# │  | 4    | 348              | Costa Sur cascadas y playa negra                     | 50 (combustible + comida)   │
# │  |                                                                                                              │
# │  | 5    | 10               | Senderismo local / relax                              | 20 (comidas + combust.) |  │
# │  | 6    | 0                | Museos y cultura                                     | 74 (entradas + comida +     │
# │  bus) |                                                                                                         │
# │  | 7    | 0                | Relax, cafés y tiendas                               | 24 (comida + bus)   |       │
# │  | 8    | 10               | Piscina geotermal Laugardalslaug                     | 40 (entrada + comida +      │
# │  combustible) |                                                                                                 │
# │  | 9    | 30               | Excursión natural local                               | 26 (comidas +              │
# │  combustible) |                                                                                                 │
# │  | 10   | 0                | Compras y paseo urbano                                | 19 (comida + transporte)   │
# │  |                                                                                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  # Costes totales aproximados del viaje                                                                         │
# │                                                                                                                 │
# │  | Categoría              | Total EUR |                                                                         │
# │  |-----------------------|-----------|                                                                          │
# │  | Vuelos BCN - KEF (2 pax)       | 380       |                                                                 │
# │  | Alojamiento Airbnb (10 noches) | 1100      |                                                                 │
# │  | Alquiler coche (10 días + seguro básico) | 320       |                                                       │
# │  | Combustible coche (estimado)   | 100       |                                                                 │
# │  | Comidas y cenas (mayoría en apartamento + 4 cenas fuera) | 200       |                                       │
# │  | Entradas museos y piscinas     | 90        |                                                                 │
# │  | Transporte público y buses      | 12        |                                                                │
# │  | **TOTAL APROXIMADO**            | **2202 EUR** |                                                             │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  # Observaciones y Recomendaciones                                                                              │
# │                                                                                                                 │
# │  - El total estimado es casi igual al presupuesto de 2200 EUR, por lo que es un plan realista y equilibrado.    │
# │  - Para control de presupuesto:                                                                                 │
# │    - Cocinar la mayoría de desayunos y cenas en Airbnb.                                                         │
# │    - Usar picnic para excursiones diarias.                                                                      │
# │    - Reservar alquiler de coche con anticipación para mejores precios (320 EUR aprox.).                         │
# │    - Priorizar actividades gratuitas o de bajo coste (senderismo, parques, museos con entradas baratas).        │
# │    - Piscinas locales geotermales son una alternativa económica a Laguna Azul (que cuesta 65 EUR/pax).          │
# │  - Se eliminan tours costosos como Laguna Jökulsárlón o cueva de hielo para mantenerse en presupuesto.          │
# │  - Este plan garantiza flexibilidad, experiencia natural y comodidad urbana en Reykjavik.                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  # Resumen final                                                                                                │
# │                                                                                                                 │
# │  | Concepto                | Coste (EUR) |                                                                      │
# │  |------------------------|-------------|                                                                       │
# │  | Vuelos ida y vuelta BCN-Reikiavik (2 personas) | 380         |                                               │
# │  | Alojamiento 10 noches (Airbnb)                   | 1100        |                                             │
# │  | Alquiler coche + seguro básico                    | 320         |                                            │
# │  | Combustible                                        | 100         |                                           │
# │  | Comidas/cenas (mix apartamento y restaurantes económicos) | 200   |                                          │
# │  | Entradas actividades, piscinas y transporte público | 102        |                                           │
# │  | **Total general**                                   | **2202 EUR** |                                         │
# │  | **Presupuesto disponible**                          | 2200 EUR    |                                          │
# │  | **Diferencia**                                      | +2 EUR      |                                          │
# │                                                                                                                 │
# │  Cumplimos el presupuesto casi exacto, maximizado para experiencia 10 días completas en Islandia.               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ¿Quieres que te prepare también una lista recomendada de supermercados, menús para cocinar y detalles para     │
# │  alquilar coche económico?                                                                                      │
# │  ¿O prefieres ayuda para reservar actividades específicas o transporte alternativo?                             │
# │                                                                                                                 │
# │  Estoy a tu disposición para afinar o ampliar el plan a tu gusto.                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# WARNING:crewai.events.listeners.tracing.trace_batch_manager:Error sending events to backend: [Errno 51] Network is unreachable. Events will be lost.
# [CrewAIEventsBus] Sync handler error in on_crew_completed: [Errno 8] nodename nor servname provided, or not known
